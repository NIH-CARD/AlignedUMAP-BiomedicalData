# %% [markdown]
# # Code to execute Aligned-UMAP

# %% [markdown]
# ## Import libraries

# %%
import copy
import os
import pickle
import sys
from collections import defaultdict
from itertools import product
from pathlib import Path

import numpy as np
import pandas as pd
from omegaconf import OmegaConf

# Code for alinged umap and interpolation
from models.umap_aligned.main import get_embedding
from utils.interpolation import interpolate_paths

# %% [markdown]
# ## Path to configuration file

# %%
config_file = "configs/alignedUMAP_configuration.yaml"

# %% [markdown]
# ## Read configuration file

# %%
# Process arguments of configuration file
config = OmegaConf.load(config_file)
visualization_method = "umap_aligned"
num_cores = config['num_cores']
if num_cores == -1:
    num_cores = os.cpu_count()

data_dir = Path(config['data_dir'])
cache_dir = Path(config['cache_dir'])
result_dir = Path(config['result_dir'])
perform_interpolation = int(config['perform_interpolation'])
dataset_name = config['dataset_name'].split('.csv')[0]
metadata_name = config['metadata_name'].split('.csv')[0]
sample_fraction = config['sample_fraction']

# %% [markdown]
# ## Read data and metadata

# %%
data = pd.read_csv(data_dir / f"{dataset_name}.csv")
data['subject_id'] = data['subject_id'].map(lambda x: str(x))
data['time_id'] = data['time_id'].map(lambda x: str(x))
if not sample_fraction == 1:
    sample_fraction = str(float(sample_fraction))
    all_subjects = list(data.subject_id.unique())
    selected_subjects = list(all_subjects[:int(len(all_subjects) * float(sample_fraction))])
    sample_text = f"_{sample_fraction}"
else:
    sample_fraction = "1.0"
    selected_subjects = list(data.subject_id.unique())
    sample_text = f"_{sample_fraction}"

data = data[data['subject_id'].isin(selected_subjects)]
data = data.set_index(['subject_id', 'time_id'])
if metadata_name == "":
    metadata = pd.DataFrame({'subject_id':data.reset_index()['subject_id'].unique()})
    metadata['color'] = 'NoColor'
else:
    metadata = pd.read_csv(data_dir / f'{metadata_name}.csv')

metadata = metadata.set_index('subject_id')
metadata.index = metadata.index.map(str)
metadata = metadata.to_dict()

# %% [markdown]
# ## Prepare list of hyperparameters

# %%
results_data = {}
output_df = []
metric_list = config['metric']
alignment_regularisation = config['alignment_regularisation']
alignment_window_size = config['alignment_window_size']
n_neighbors = config['n_neighbors']
min_dist = config['min_dist']
input_parameters = []
op = 0
for reg, ws in list(product(alignment_regularisation, alignment_window_size)):
    for neig, dist, metric in list(product(n_neighbors, min_dist, metric_list)):
        op += 1
        temp = {}
        temp['metric'] = metric
        temp['alignment_regularisation'] = reg
        temp['alignment_window_size'] = ws
        temp['n_neighbors'] = neig
        temp['min_dist'] = dist
        temp['num_cores'] = num_cores
        temp['sample_fraction'] = sample_fraction
        temp['id'] = ';'.join([f"{i}={j}" for i, j in temp.items()])
        temp['alignment_regularisation'] = float(reg)
        temp['alignment_window_size'] = int(ws)
        temp['n_neighbors'] = int(neig)
        temp['min_dist'] = float(dist)
        temp['min_dist'] = float(dist)
        input_parameters.append(copy.deepcopy(temp))

print('-' * 50, "Executing", '-' * 50)
print('Dataset filename:', dataset_name, '|', 'Metadata filename:', metadata_name)
print('Number of hyper parameters', len(input_parameters))
# Out:
# -------------------------------------------------- Executing --------------------------------------------------
# Dataset filename: example_PPMI_clinical_assessment_data | Metadata filename: example_metadata_PPMI_clinical_assessment_data
# Number of hyper parameters 48

# %% [markdown]
# ## Apply Aligned-UMAP for all hyperparameters

# %%
feature_name = dataset_name
selected_feature = np.array([True] * len(data.columns))
for e_inp, input_parameter in enumerate(input_parameters):
    print('-' * 50, f'Hyper parameter (index={e_inp})', '-' * 50)
    print(input_parameter)
    print('-' * 50, '-' * 50)
    embeddings, V, T1_data, age_list, time_taken = get_embedding(data, selected_feature, feature_name, data_dir=cache_dir, input_parameter=input_parameter)
    df = pd.DataFrame(np.vstack(embeddings), columns=('x', 'y'))
    df['z'] = np.concatenate([[year] * len(embeddings[i]) for i, year in enumerate(range(len(age_list)))])
    df['subject_id'] = np.concatenate([v.index for v in V])
    df['feature_group'] = [feature_name] * len(df)
    for key, val in metadata.items():
        df[key] = df['subject_id'].map(lambda x: val.get(str(x), 'UNK'))
    df['input_parameter_id'] = [input_parameter['id']] * len(df)
    trace_inputs = []
    extended_interpolated_data = {}
    if perform_interpolation:
        for rep in df.subject_id.unique():
            z = df.z[df.subject_id == rep].values
            x = df.x[df.subject_id == rep].values
            y = df.y[df.subject_id == rep].values
            l = interpolate_paths(z, x, y, rep)
            trace_inputs.append(l)
        extended_interpolated_data = defaultdict(list)
        for trace_input in trace_inputs:
            for z, x, y, rep in trace_input:
                extended_interpolated_data['x'].extend(x)
                extended_interpolated_data['z'].extend(z)
                extended_interpolated_data['y'].extend(y)
                extended_interpolated_data['text'].extend(rep)
        extended_interpolated_data = pd.DataFrame(extended_interpolated_data)
        extended_interpolated_data['z'] = extended_interpolated_data['z'].map(lambda x: format(round(x, 2), '.2f'))
        extended_interpolated_data['z'] = extended_interpolated_data['z'].map(lambda x: f"z-{x}")
        extended_interpolated_data = extended_interpolated_data.rename(columns={'text': 'subject_id', 'z': 'time_id'})
        extended_interpolated_data['subject_id'] = extended_interpolated_data['subject_id'].map(str)
        extended_interpolated_data = extended_interpolated_data.set_index(['subject_id', 'time_id'])
    output_df.append(df)
    results_data[f"{feature_name}-{input_parameter['id']}"] = {
            'data': df.copy(),
            'trace_inputs': copy.deepcopy(trace_inputs),
            'embeddings': copy.deepcopy(embeddings),
            'time_taken': time_taken,
            'extended_interpolated_data': extended_interpolated_data
        }
# Out:
# -------------------------------------------------- Hyper parameter (index=0) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:29
# Completed at: 2023-01-21 14:56:38
# Total time taken (hh:mm:ss): 0:00:09
# -------------------------------------------------- Hyper parameter (index=1) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:38
# Completed at: 2023-01-21 14:56:42
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=2) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:42
# Completed at: 2023-01-21 14:56:46
# Total time taken (hh:mm:ss): 0:00:03
# -------------------------------------------------- Hyper parameter (index=3) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:46
# Completed at: 2023-01-21 14:56:50
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=4) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:50
# Completed at: 2023-01-21 14:56:54
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=5) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:55
# Completed at: 2023-01-21 14:56:59
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=6) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:56:59
# Completed at: 2023-01-21 14:57:03
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=7) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:03
# Completed at: 2023-01-21 14:57:07
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=8) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:08
# Completed at: 2023-01-21 14:57:12
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=9) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:12
# Completed at: 2023-01-21 14:57:17
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=10) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:17
# Completed at: 2023-01-21 14:57:22
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=11) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=2;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:22
# Completed at: 2023-01-21 14:57:26
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=12) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:27
# Completed at: 2023-01-21 14:57:31
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=13) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:31
# Completed at: 2023-01-21 14:57:35
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=14) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:36
# Completed at: 2023-01-21 14:57:39
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=15) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:40
# Completed at: 2023-01-21 14:57:44
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=16) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:44
# Completed at: 2023-01-21 14:57:49
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=17) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:49
# Completed at: 2023-01-21 14:57:54
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=18) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:54
# Completed at: 2023-01-21 14:57:59
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=19) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:57:59
# Completed at: 2023-01-21 14:58:04
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=20) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:04
# Completed at: 2023-01-21 14:58:10
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=21) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:10
# Completed at: 2023-01-21 14:58:15
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=22) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:16
# Completed at: 2023-01-21 14:58:20
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=23) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.003, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.003;alignment_window_size=3;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:21
# Completed at: 2023-01-21 14:58:26
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=24) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:26
# Completed at: 2023-01-21 14:58:30
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=25) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:30
# Completed at: 2023-01-21 14:58:34
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=26) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:34
# Completed at: 2023-01-21 14:58:38
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=27) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:38
# Completed at: 2023-01-21 14:58:42
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=28) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:43
# Completed at: 2023-01-21 14:58:47
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=29) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:47
# Completed at: 2023-01-21 14:58:51
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=30) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:51
# Completed at: 2023-01-21 14:58:55
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=31) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:58:56
# Completed at: 2023-01-21 14:59:00
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=32) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:00
# Completed at: 2023-01-21 14:59:05
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=33) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:05
# Completed at: 2023-01-21 14:59:10
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=34) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:10
# Completed at: 2023-01-21 14:59:14
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=35) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 2, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=2;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:15
# Completed at: 2023-01-21 14:59:19
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=36) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:20
# Completed at: 2023-01-21 14:59:24
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=37) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=03;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:24
# Completed at: 2023-01-21 14:59:28
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=38) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:28
# Completed at: 2023-01-21 14:59:32
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=39) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 3, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=03;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:32
# Completed at: 2023-01-21 14:59:36
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=40) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:37
# Completed at: 2023-01-21 14:59:41
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=41) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=05;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:41
# Completed at: 2023-01-21 14:59:46
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=42) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:46
# Completed at: 2023-01-21 14:59:50
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=43) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 5, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=05;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:51
# Completed at: 2023-01-21 14:59:55
# Total time taken (hh:mm:ss): 0:00:04
# -------------------------------------------------- Hyper parameter (index=44) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 14:59:55
# Completed at: 2023-01-21 15:00:00
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=45) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.01, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=10;min_dist=0.01;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 15:00:01
# Completed at: 2023-01-21 15:00:06
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=46) --------------------------------------------------
# {'metric': 'euclidean', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=euclidean;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 15:00:06
# Completed at: 2023-01-21 15:00:11
# Total time taken (hh:mm:ss): 0:00:05
# -------------------------------------------------- Hyper parameter (index=47) --------------------------------------------------
# {'metric': 'cosine', 'alignment_regularisation': 0.03, 'alignment_window_size': 3, 'n_neighbors': 10, 'min_dist': 0.1, 'num_cores': 10, 'sample_fraction': '1.0', 'id': 'metric=cosine;alignment_regularisation=0.030;alignment_window_size=3;n_neighbors=10;min_dist=0.10;num_cores=10;sample_fraction=1.0'}
# -------------------------------------------------- --------------------------------------------------
# Aligned UMAP running...
# Starts at: 2023-01-21 15:00:11
# Completed at: 2023-01-21 15:00:16
# Total time taken (hh:mm:ss): 0:00:05

# %% [markdown]
# ## Save all embeddings

# %%
output_df = pd.concat(output_df, axis=0)
results_data['complete_dataframe'] = output_df
results_data['sample_size'] = len(selected_subjects)
results_data['feature_size'] = data.shape[0]
results_data['time_sequence'] = data.reset_index()['time_id'].unique().shape[0]
results_data['age_list'] = age_list
os.makedirs(result_dir / f"{dataset_name}/{visualization_method}/generated_data", exist_ok=True)
with open(result_dir / f"{dataset_name}/{visualization_method}/generated_data/{dataset_name}_{num_cores}{sample_text}.pickle", 'wb') as handle:
    pickle.dump(results_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

print('-' * 50, '-' * 50)
print("Congratulations!")
print("Summarized results for all hyper parameters:", result_dir / f"{dataset_name}/{visualization_method}/generated_data/{dataset_name}_{num_cores}{sample_text}.pickle")
# Out:
# -------------------------------------------------- --------------------------------------------------
# Congratulations!
# Summarized results for all hyper parameters: results_data/example_PPMI_clinical_assessment_data/umap_aligned/generated_data/example_PPMI_clinical_assessment_data_10_1.0.pickle
